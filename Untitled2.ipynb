# %%
from pylab import *

xverdi = []
yverdi =[]

def f(x):
    return x*exp(x)
def g(x):
    return x**2

def der(f,x,dx = 1E-1):
    fder = (f(x+dx)-f(x-dx))/2*dx
    return fder

for i in range (10,21):
    x = i/10
    xverdi.append(x)
    yverdi.append(der(f,x,)*100)
    print(der(f,x))
    
plot(xverdi,yverdi)
show()
# Out:
# 0.054546991314991106
# 0.06329292394124067
# 0.07327515207819715
# 0.08465698231493446
# 0.09762239688010409
# 0.11237859627248202
# 0.1291588480214573
# 0.14822567784555615
# 0.16987444371971874
# 0.1944373380959001
# 0.222287868803073
