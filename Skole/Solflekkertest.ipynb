# %% [markdown]
# # Datahåndtering

# %%
from pylab import *

data = loadtxt("solflekker.txt", skiprows = 1)

tid = data[:,0]
solflekker = data[:,1]

plot(tid,solflekker, color = "forestgreen")
xlabel("Tid (md.etter 1. januar 1749)")
ylabel("Gjennomsnittlig antall solflekker")
show()

# %%
tid
# Out:
# array([0.000e+00, 1.000e+00, 2.000e+00, ..., 3.140e+03, 3.141e+03,
#        3.142e+03])
