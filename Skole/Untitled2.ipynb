# %%
from pylab import *

data = loadtxt("Ledefinger.csv", skiprows = 1, delimiter = ";")
data.sort()

tommel = data[:,0]
peke = data[:,1]


t = mean(tommel)
p = mean(peke)

print(p,t)

plot(tommel,peke)
show()
# Out:
# 14.75 11.0
