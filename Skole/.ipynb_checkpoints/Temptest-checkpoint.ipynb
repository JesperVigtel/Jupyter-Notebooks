# %% [markdown]
# # Tempreratur

# %%
from pylab import *

data = loadtxt("temperatur.txt",skiprows = 1)

tid = data[:,0]
temp = data [:,1]

plot(tid,temp,color = "hotpink")
xlabel("tid (min)")
ylabel("Temperatur (C)")
show()
